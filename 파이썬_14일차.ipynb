# %% [markdown]
# <a href="https://colab.research.google.com/github/mos00312/python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_14%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 1
print('==CLI 게시판 실행==')
while num <3: # 2번째 만아니라 계속 쓸수있게 만들려면?
 title = input() #input에 쓴 내용을 지우는방법?
 mean = input()
 command = input()
 print('제목:{}'.format(title))
 print('내용:{}'.format(mean))
 print('{}번글이 생성되었습니다'.format(num))
 num+=1
print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 안
# 안ㅇ
# 명령어 )난
# 제목:안
# 제목:안
# 내용:안ㅇ
# 1번글이 생성되었습니다
# 아
# 앙
# 명령어 )안아
# 제목:아
# 제목:아
# 내용:앙
# 2번글이 생성되었습니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1423/512788460.py in <cell line: 0>()
#       2 print('==CLI 게시판 실행==')
#       3 while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
# ----> 4  title = input() #input에 쓴 내용을 지우는방법?
#       5  mean = input()
#       6  command = input('명령어 )')
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
num = 1
print('==CLI 게시판 실행==')
while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
 command = input('명령어 : ')
 if command == 'exit':
  break
 elif command == 'article write':
  input('제목 : ')
  input('내용 : ')
  print('{}번글이 생성되었습니다'.format(num))
 num+=1
print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 명령어 : article write
# 제목 : 안녕
# 내용 : 라아아아아
# 1번글이 생성되었습니다
# 명령어 : article write
# 제목 : ㅎㅇ
# 내용 : ㅇㄴㅁ이ㅏㄴㅁ이;
# 2번글이 생성되었습니다
# 명령어 : article write
# 제목 : ㅇ
# 내용 : ㅇ
# 3번글이 생성되었습니다
# 명령어 : ㄷ턋
# 명령어 : exit
# ==CLI 게시판 종료==

# %%
#== CLI 게시판 실행 ==
#명령어 ) article write (사용자의 입력)
#제목 : 123 (사용자의 입력)
#내용 : abc (사용자의 입력)
#1번 글이 생성 되었습니다.
#명령어 ) article write (사용자의 입력)
#제목 : 456 (사용자의 입력)
#내용 : def (사용자의 입력)
#2번 글이 생성 되었습니다.
#명령어 ) article list
#=========================================
#번호      /     제목       /     내용
#  2       /     456        /     def
#  1       /     123        /     abc
#=========================================
#명령어 ) exit (사용자의 입력)
#== CLI 게시판 종료 ==

num = 0
data = {
    '번호' : [],
    '제목' : [],
    '내용': []
    }
article_list = data
print('==CLI 게시판 실행==')
while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
 command = input('명령어 : ')
 if command == 'exit':
  break
 elif command == 'article write':
  num+=1
  title = input('제목 : ')
  mean = input('내용 : ')
  data['번호'].append(num)
  data['제목'].append(title)
  data['내용'].append(mean)
  print('{}번글이 생성되었습니다'.format(num))

 elif command ==  'article list':
  print(article_list)


print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 명령어 : article write
# 제목 : 안녕
# 내용 : ㅎㅇ
# 2번글이 생성되었습니다
# 명령어 : article write
# 제목 : 안녕ㅇㅇㅇㅇ
# 내용 : ㅎㅇㅇㅇㅇㅇ
# 3번글이 생성되었습니다
# 명령어 : article ㅣㅑㄴㅅ
# 명령어 : article list
# {'번호': [2, 3], '제목': ['안녕', '안녕ㅇㅇㅇㅇ'], '내용': ['ㅎㅇ', 'ㅎㅇㅇㅇㅇㅇ']}
# 명령어 : exit
# ==CLI 게시판 종료==

# %%
print("== CLI 게시판 실행 ==")
last_article_id = 0
articles = []

while True:
  command = input("명령어 ) ").strip()

  if command == "exit":
    break

  elif command == "article write":
    last_article_id += 1
    id = last_article_id
    title = input("제목 : ")
    contants = input("내용 : ")

    article = {"id" : id, "title" : title, "contants" : contants}
    articles.append(article)

    print("{}번 글이 생성되었습니다".format(last_article_id))
  elif command == "article list":
    if not articles:
      print("게시글이 없어")
    else:
      print("=========================================")
      print("   번호      /     제목       /     내용    ")
      for a in reversed(articles):
        print("    {}      /     {}       /     {}    ".format(a["id"],a["title"],a["contants"]))
      print("=========================================")

  else:
    print("지원하지 않는 명령어입니다.")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : s
# 내용 : s
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : w
# 내용 : w
# 2번 글이 생성되었습니다
# 명령어 ) article delete 1
# 지원하지 않는 명령어입니다.
# 명령어 ) exit
# == CLI 게시판 종료 ==

# %%
print("== CLI 게시판 실행 ==")
last_article_id = 0
articles = []
article_delete_list = [] #삭제당한 게시글 리스트
a = 0
while True:
  command = input("명령어 ) ").strip()

  if command == "exit":
    break

  elif command == "article write":
    last_article_id += 1
    id = last_article_id
    title = input("제목 : ")
    contants = input("내용 : ")

    article = {"id" : (id), "title" : title, "contants" : contants}
    articles.append(article)

    print("{}번 글이 생성되었습니다".format(last_article_id))
  elif command == "article list":
    if not articles:
      print("게시글이 없어")
    else:
      print("=========================================")
      print("   번호      /     제목       /     내용    ")
      for a in reversed(articles):
        print("    {}      /     {}       /     {}    ".format(a["id"],a["title"],a["contants"]))
      print("=========================================")
  elif command.startswith("article delete"):
    command_Bits = command.split(" ")
    for article in articles:

      if article["id"] == int(command_Bits[2]):
        article_delete_list.append(article)
        articles.remove(article)




    print("{}번 글이 삭제되었습니다".format(command_Bits[2]))
  else:
    print("지원하지 않는 명령어입니다.")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : fdsjkl
# 내용 : gdfkjgkfd
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : fdsljfdsklj
# 내용 : fdsjlkfsdjklfj
# 2번 글이 생성되었습니다
# 명령어 ) article delete 1
# 1번 글이 삭제되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     2      /     fdsljfdsklj       /     fdsjlkfsdjklfj
# ...
# 명령어 ) article write
# 제목 : 3
# 내용 : g
# 3번 글이 생성되었습니다
# 명령어 ) article delete 1
# 1번 글이 삭제되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     3      /     3       /     g
#     2      /     fdsljfdsklj       /     fdsjlkfsdjklfj
# ...
# 명령어 ) exit
# == CLI 게시판 종료 ==

# %%
from datetime import datetime

time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(time)
# Out:
# 2026-09-01 02:35:00

# %%
from datetime import datetime

print("== CLI 게시판 실행 ==")
last_article_id = 1
articles = [{"id" : 1, "regDate" : "2026-08-31 12:12:12", "updateDate" : "2026-08-31 12:12:12", "title" : "제목1", "body" : "내용1"}]


while True:
  cmd = input("명령어 ) ").strip()

  if cmd == "exit":
    break

  elif cmd == "article write":
    last_article_id += 1
    id = last_article_id
    regDate = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    updateDate = regDate
    title = input("제목 : ")
    body = input("내용 : ")

    article = {"id" : id, "regDate" : regDate, "updateDate" : updateDate, "title" : title, "body" : body}
    articles.append(article)

    print("{}번 글이 생성되었습니다".format(last_article_id))
  elif cmd == "article list":
    if not articles:
      print("게시글이 없어")
    else:
      today = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
      print("=========================================")
      print("   번호      /     제목       /     내용         /     날짜    ")
      for a in reversed(articles):
        if today.split(" ")[0] != a["regDate"].split(" ")[0]:
          print("    {}      /     {}       /     {}         /     {}    ".format(a["id"],a["title"],a["body"],a["regDate"].split(" ")[0]))
        if today.split(" ")[0] == a["regDate"].split(" ")[0]:
          print("    {}      /     {}       /     {}         /     {}    ".format(a["id"],a["title"],a["body"],a["regDate"].split(" ")[1]))
      print("=========================================")
  elif cmd.startswith("article delete"):
    cmdBits = cmd.split(" ")

    if len(cmdBits) < 3:
      print("명령어 똑바로 써라(길이 모자람)")
      continue

    if not cmdBits[2].isdigit() :
      print("명령어 똑바로 써라(번호 대신 str 있는듯?)")
      continue

    deletedId = int(cmdBits[2])

    found = False

    for article in articles:
      if article["id"] == deletedId:
        articles.remove(article)
        print("{}번 글 삭제됨".format(cmdBits[2]))
        found = True
        break

    if found == False:
      print("{}번 글은 없던데?".format(cmdBits[2]))

    # for ~ else 도 있음
  elif cmd.startswith("article edit"):
    cmdBits = cmd.split(" ")

    if len(cmdBits) < 3:
      print("명령어 똑바로 써라(길이 모자람)")
      continue

    if not cmdBits[2].isdigit() :
      print("명령어 똑바로 써라(번호 대신 str 있는듯?)")
      continue

    editedId = int(cmdBits[2])

    found = False

    for article in articles:
      if article["id"] == editedId:
        # 기존 제목 내용 보여주기
        print("기존 제목 : {}".format(article["title"]))
        print("기존 내용 : {}".format(article["body"]))
        # 새로 제목 내용 입력받아서 기존 내용 업데이트
        article["title"] = input("새 제목 : ")
        article["body"] = input("새 내용 : ")
        article["updateDate"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        print("{}번 글 수정됨".format(cmdBits[2]))
        found = True
        break

    if found == False:
      print("{}번 글은 없던데?".format(cmdBits[2]))
  elif cmd.startswith("article detail"):
    cmdBits = cmd.split(" ")

    if len(cmdBits) < 3:
      print("명령어 똑바로 써라(길이 모자람)")
      continue

    if not cmdBits[2].isdigit() :
      print("명령어 똑바로 써라(번호 대신 str 있는듯?)")
      continue

    detailId = int(cmdBits[2])

    found = False

    for article in articles:
      if article["id"] == detailId:
        #자세히 보여주기
        print("==상세보기==")
        print("번호 : {}".format(article["id"]))
        print("작성 날짜 : {}".format(article["regDate"]))
        print("수정 날짜 : {}".format(article["updateDate"]))
        print("제목 : {}".format(article["title"]))
        print("내용 : {}".format(article["body"]))
        found = True
        break

    if found == False:
      print("{}번 글은 없던데?".format(cmdBits[2]))
  else:
    print("지원하지 않는 명령어입니다.")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : s
# 내용 : g
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : fds
# 내용 : hjfg
# 2번 글이 생성되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용         /     날짜
#     2      /     fds       /     hjfg         /     05:29:26
#     1      /     s       /     g         /     05:29:22
# ...
# 명령어 ) exit
# == CLI 게시판 종료 ==

# %%
# 1. 가장 최신 상태
from datetime import datetime

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article["id"] == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-09-01"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def makeTestData():
  # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
  # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
  return [
      {"id" : 1, "regDate" : "2025-12-12 12:12:12", "updateDate" : "2025-12-12 12:12:12", "title" : "제목1","body":"내용1"},
      {"id" : 2, "regDate" : now(), "updateDate" : now(), "title" : "제목2","body":"내용2"},
      {"id" : 3, "regDate" : now(), "updateDate" : now(), "title" : "제목3","body":"내용3"}
          ]

# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 3
articles = makeTestData()

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = {
            "id": last_article_id,
            "regDate": now(),
            "updateDate": now(),
            "title": title,
            "body": body,
        }
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a["id"], a["title"], a["body"], format_date(a["regDate"])))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article["title"]))
        print("기존 내용 : {}".format(article["body"]))
        article["title"] = input("새 제목 : ")
        article["body"] = input("새 내용 : ")
        article["updateDate"] = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article["id"]))
        print("작성 날짜 : {}".format(article["regDate"]))
        print("수정 날짜 : {}".format(article["updateDate"]))
        print("제목 : {}".format(article["title"]))
        print("내용 : {}".format(article["body"]))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : dsa
# 내용 : gfd
# 1번 글이 생성되었습니다
# 명령어 ) article list
# 번호 / 제목 / 작성일시
# 1 / dsa / 2026-09-01 06:02:49
# 명령어 ) exit

# %%
from datetime import datetime

def now():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def format_date(date_str):
    dt = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")
    if dt.date() == datetime.now().date():
        return dt.strftime("%H:%M:%S")
    return dt.strftime("%Y-%m-%d")

def parse_id(cmd):
    cmdBits = cmd.split(" ") # 명령어가 들어오면 띄어쓰기를 기준으로 쪼갬
    if len(cmdBits) < 3: # 쪼갠것중 3번째 문단 이 3보다 작으면 실행
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit(): # 숫자가 있는지확인
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, id): # 게시판 번호를 바꿔줌
    for article in articles:
        if article["id"] == id:
            return article
    return None

print("== CLI 게시판 실행 ==")
last_article_id = 0
articles = []
article_delete_list = []
Members = []
a = 0

while True:
  command = input("명령어 ) ").strip() # 명령어를 사용자지정

  if command == "exit": # 명령어가 exit인 경우 끝
    break
  elif command == "join": # join이라는 명령어를 입력받으면 회원가입
     while True:
      member_id = input("아이디 : ") # 아이디 중복확인 방법
      if Members is None:
        continue
      elif member_id == Members["아이디"]:
        print("이미 있는 아이디 입니다")
      else:
        continue


      member_password = input("비밀번호 : ")
      member_password_try = input("비밀번호확인 : ")
      if member_password == member_password_try:
        Member = {
          "아이디" : member_id,
          "비밀번호" : member_password

          }
      Members.append(Member)
      print("회원가입 완료")
      print(Members)
      if member_password != member_password_try: # 비밀번호를 다르게 입력하면 다시입력하라고 말해줌
        print("비밀번호를 똑같이 입력해주세요")
      False

  elif command == "article write": # 명령어가 article write 인경우 실행
    last_article_id += 1
    id = last_article_id
    title = input("제목 : ") # 제목과 내용을 사용자지정
    contants = input("내용 : ")

    article = {
        "id" : (id),
        "title" : title,
        "contants" : contants,
        "reg_date" : now()
    }
    articles.append(article) # article을 articles에 추가

    print("{}번 글이 생성되었습니다".format(last_article_id)) #게시글이 추가될때마다 1씩증가

  elif command == "article list": # 게시글 목록을 보고싶을때 사용
    if len(articles) == 0:
      print("게시글이 존재하지 않습니다.")
      continue

    print("번호 / 제목 / 작성일시") # 게시글 목록의 큰틀
    for article in articles:
      print("{} / {} / {}".format(article["id"], article["title"], format_date(article["reg_date"])))

  elif command.startswith("article detail"):
    id = parse_id(command)
    if id is None:
      continue

    article = find_article(articles, id)
    if article is None:
      print("{}번 게시글은 존재하지 않습니다.".format(id))
      continue

    print("번호 : {}".format(article["id"]))
    print("작성일시 : {}".format(format_date(article["reg_date"])))
    print("제목 : {}".format(article["title"]))
    print("내용 : {}".format(article["contants"]))

  elif command.startswith("article modify"):
    id = parse_id(command)
    if id is None:
      continue

    article = find_article(articles, id)
    if article is None:
      print("{}번 게시글은 존재하지 않습니다.".format(id))
      continue

    title = input("새 제목 : ")
    contants = input("새 내용 : ")

    article["title"] = title
    article["contants"] = contants
    print("{}번 게시글이 수정되었습니다.".format(id))

  elif command == "article delete list":
    if len(article_delete_list) == 0:
      print("삭제된 게시글이 없습니다.")
      continue

    print("== 삭제된 게시글 목록 ==")
    for article in article_delete_list:
      print("{} / {} / {}".format(article["id"], article["title"], format_date(article["reg_date"])))

  elif command.startswith("article delete"):
    id = parse_id(command)
    if id is None:
      continue

    article = find_article(articles, id)
    if article is None:
      print("{}번 게시글은 존재하지 않습니다.".format(id))
      continue

    articles.remove(article)
    article_delete_list.append(article)
    print("{}번 게시글이 삭제되었습니다.".format(id))

  else:
    print("존재하지 않는 명령어입니다.")
print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) join
# 아이디 : 123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1035/2879109091.py in <cell line: 0>()
#      43       if Members is None:
#      44         continue
# ---> 45       elif member_id == Members["아이디"]:
#      46         print("이미 있는 아이디 입니다")
#      47       else:
#
# TypeError: list indices must be integers or slices, not str
