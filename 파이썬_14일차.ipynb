# %% [markdown]
# <a href="https://colab.research.google.com/github/mos00312/python/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_14%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 1
print('==CLI 게시판 실행==')
while num <3: # 2번째 만아니라 계속 쓸수있게 만들려면?
 title = input() #input에 쓴 내용을 지우는방법?
 mean = input()
 command = input()
 print('제목:{}'.format(title))
 print('내용:{}'.format(mean))
 print('{}번글이 생성되었습니다'.format(num))
 num+=1
print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 안
# 안ㅇ
# 명령어 )난
# 제목:안
# 제목:안
# 내용:안ㅇ
# 1번글이 생성되었습니다
# 아
# 앙
# 명령어 )안아
# 제목:아
# 제목:아
# 내용:앙
# 2번글이 생성되었습니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1423/512788460.py in <cell line: 0>()
#       2 print('==CLI 게시판 실행==')
#       3 while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
# ----> 4  title = input() #input에 쓴 내용을 지우는방법?
#       5  mean = input()
#       6  command = input('명령어 )')
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
num = 1
print('==CLI 게시판 실행==')
while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
 command = input('명령어 : ')
 if command == 'exit':
  break
 elif command == 'article write':
  input('제목 : ')
  input('내용 : ')
  print('{}번글이 생성되었습니다'.format(num))
 num+=1
print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 명령어 : article write
# 제목 : 안녕
# 내용 : 라아아아아
# 1번글이 생성되었습니다
# 명령어 : article write
# 제목 : ㅎㅇ
# 내용 : ㅇㄴㅁ이ㅏㄴㅁ이;
# 2번글이 생성되었습니다
# 명령어 : article write
# 제목 : ㅇ
# 내용 : ㅇ
# 3번글이 생성되었습니다
# 명령어 : ㄷ턋
# 명령어 : exit
# ==CLI 게시판 종료==

# %%
#== CLI 게시판 실행 ==
#명령어 ) article write (사용자의 입력)
#제목 : 123 (사용자의 입력)
#내용 : abc (사용자의 입력)
#1번 글이 생성 되었습니다.
#명령어 ) article write (사용자의 입력)
#제목 : 456 (사용자의 입력)
#내용 : def (사용자의 입력)
#2번 글이 생성 되었습니다.
#명령어 ) article list
#=========================================
#번호      /     제목       /     내용
#  2       /     456        /     def
#  1       /     123        /     abc
#=========================================
#명령어 ) exit (사용자의 입력)
#== CLI 게시판 종료 ==
num = 1
data = {
    '번호' : [],
    '제목' : [],
    '내용': []
    }
article_list =pd.DataFrame(data)
print('==CLI 게시판 실행==')
while True: # 2번째 만아니라 계속 쓸수있게 만들려면?
 command = input('명령어 : ')
 if command == 'exit':
  break
 elif command == 'article write':
  title = input('제목 : ')

  mean = input('내용 : ')
  print('{}번글이 생성되었습니다'.format(num))
 #elif command ==  'article list':

 num+=1
print('==CLI 게시판 종료==')
# Out:
# ==CLI 게시판 실행==
# 명령어 : article write
# 제목 : gd
# 내용 : gd
# 1번글이 생성되었습니다
# 명령어 : article write
# 제목 : gdhdfg
# 내용 : dsa
# 2번글이 생성되었습니다
# 명령어 : exit
# ==CLI 게시판 종료==

# %%
import pandas as pd
data = {
    '번호' : [],
    '제목' : [],
    '내용': []
    }

article_list = pd.DataFrame(data)
title = input('제목 : ')
data.append[2] = title
print(article_list)
# Out:
# 제목 : d
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1423/3674706965.py in <cell line: 0>()
#       8 article_list = pd.DataFrame(data)
#       9 title = input('제목 : ')
# ---> 10 data.append[2] = title
#      11 print(article_list)
#
# AttributeError: 'dict' object has no attribute 'append'
